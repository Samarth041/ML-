# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')

# %% [markdown]
# <h2>How big is the Data</h2>

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# <h2>How does the data look like</h2>

# %%
df.sample(5) #Returns random rows from the DataFrame.

#Picks 5 random rows, different each time.
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 800          801         0       2                     Ponesell, Mr. Martin
# 592          593         0       3               Elsbury, Mr. William James
# 765          766         1       1     Hogeboom, Mrs. John C (Anna Andrews)
# 255          256         1       3  Touma, Mrs. Darwis (Hanne Youssef Razi)
# 337          338         1       1          Burns, Miss. Elizabeth Margaret
#
#         Sex   Age  SibSp  Parch    Ticket      Fare Cabin Embarked
# 800    male  34.0      0      0    250647   13.0000   NaN        S
# 592    male  47.0      0      0  A/5 3902    7.2500   NaN        S
# 765  female  51.0      1      0     13502   77.9583   D11        S
# 255  female  29.0      0      2      2650   15.2458   NaN        C
# 337  female  41.0      0      0     16966  134.5000   E40        C

# %% [markdown]
# <h2>.sample()</h2>
#
# gives 1 random row everytime
# If we want to increase row then give specified number like <b>df.sample(4)</b>
#
# if we want same output use : <b>data.sample(5, random_state=42)</b>

# %% [markdown]
# <h2>What is the data type of cols?</h2>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# <h2>Are there any missing values?</h2>

# %%
df.isnull().sum() #it tells how many null values are present column wise
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# <h2>How does the data look mathematically?</h2>

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# <h2> Are there duplicate values?</h2>

# %%
df.duplicated().sum() #it considers all columns together to decide duplication.

#Counts how many rows are duplicate rows
# Out:
# np.int64(0)

# %% [markdown]
# <h4>if want column wise name</h4>
#
# <b>then write df['column_name'].duplicated().sum()</b>

# %%
df['PassengerId'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <h2>How is the correlation between cols?</h2>

# %%
df.corr(numeric_only=True)['Survived']
#👉 It gives the correlation of every numeric column with the target column Survived
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64
